# %%
# !pip install ultralytics roboflow
# Out:
# Requirement already satisfied: ultralytics in d:\projects\licenseplatereader\.venv\lib\site-packages (8.4.30)
# Collecting roboflow
#   Downloading roboflow-1.2.16-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.23.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from ultralytics) (2.4.3)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in d:\projects\licenseplatereader\.venv\lib\site-packages (from ultralytics) (12.1.1)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\projects\licenseplatereader\.venv\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from ultralytics) (2.33.0)
# Requirement already satisfied: scipy>=1.4.1 in d:\projects\licenseplatereader\.venv\lib\site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from ultralytics) (2.11.0)
# Requirement already satisfied: torchvision>=0.9.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from ultralytics) (0.26.0)
# Requirement already satisfied: psutil>=5.8.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from ultralytics) (1.39.3)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in d:\projects\licenseplatereader\.venv\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: certifi in d:\projects\licenseplatereader\.venv\lib\site-packages (from roboflow) (2026.2.25)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in d:\projects\licenseplatereader\.venv\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\projects\licenseplatereader\.venv\lib\site-packages (from roboflow) (1.5.0)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp313-cp313-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: python-dateutil in d:\projects\licenseplatereader\.venv\lib\site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: six in d:\projects\licenseplatereader\.venv\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in d:\projects\licenseplatereader\.venv\lib\site-packages (from roboflow) (2.6.3)
# Collecting tqdm>=4.41.0 (from roboflow)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting requests-toolbelt (from roboflow)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.3.0-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in d:\projects\licenseplatereader\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.62.1)
# Requirement already satisfied: packaging>=20.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=3 in d:\projects\licenseplatereader\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: polars-runtime-32==1.39.3 in d:\projects\licenseplatereader\.venv\lib\site-packages (from polars>=0.20.0->ultralytics) (1.39.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\projects\licenseplatereader\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.6)
# Requirement already satisfied: filelock in d:\projects\licenseplatereader\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in d:\projects\licenseplatereader\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\projects\licenseplatereader\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\projects\licenseplatereader\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in d:\projects\licenseplatereader\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in d:\projects\licenseplatereader\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: colorama in d:\projects\licenseplatereader\.venv\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\projects\licenseplatereader\.venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading roboflow-1.2.16-py3-none-any.whl (95 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Downloading pi_heif-1.3.0-cp313-cp313-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    -------------------------- ------------- 1.3/1.9 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 3.1 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp313-cp313-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.9 MB 8.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.9 MB 6.3 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.9 MB 6.2 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.9 MB 6.3 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.9 MB 6.3 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/9.9 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 5.6 MB/s eta 0:00:00
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, tqdm, python-dotenv, pi-heif, opencv-python-headless, idna, requests-toolbelt, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.3.0 pillow-avif-plugin-1.5.5 python-dotenv-1.2.2 requests-toolbelt-1.0.0 roboflow-1.2.16 tqdm-4.67.3
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="kd6dS93MyPU4hTkxBZ9V")  # Will prompt you to log in (free account)
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in License-Plate-Recognition-4 to yolov8:: 100%|██████████| 974784/974784 [02:30<00:00, 6487.05it/s]
# Extracting Dataset Version Zip to License-Plate-Recognition-4 in yolov8:: 100%|██████████| 48488/48488 [01:47<00:00, 449.82it/s]
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\andre\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")  # nano = lightweight
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=45,
    imgsz=640,
    batch=16,
    name="plate_detector"
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 5.3MB/s 1.2s.1s<0.1s.4s
# Ultralytics 8.4.30  Python-3.13.3 torch-2.11.0+cpu CPU (AMD Ryzen 7 4800H with Radeon Graphics)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=d:\PROJECTS\licenseplatereader\License-Plate-Recognition-4/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=45, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=plate_detector, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\PROJECTS\licenseplatereader\runs\detect\plate_detector, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Matplotlib is building the font cache; this may take a moment.
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\andre\AppData\Roaming\Ultralytics\Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 1.5MB/s 0.5s 0.4s<0.1s2s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.70.3 ms, read: 2.10.3 MB/s, size: 43.1 KB)
# train: Scanning D:\PROJECTS\licenseplatereader\License-Plate-Recognition-4\train\labels... 21173 images, 28 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 21173/21173 177.0it/s 1:60<0.1s
# train: New cache created: D:\PROJECTS\licenseplatereader\License-Plate-Recognition-4\train\labels.cache
# val: Fast image access  (ping: 0.40.1 ms, read: 2.20.6 MB/s, size: 39.1 KB)
# val: Scanning D:\PROJECTS\licenseplatereader\License-Plate-Recognition-4\valid\labels... 2046 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2046/2046 192.8it/s 10.6s0.1s
# val: New cache created: D:\PROJECTS\licenseplatereader\License-Plate-Recognition-4\valid\labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to D:\PROJECTS\licenseplatereader\runs\detect\plate_detector\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\PROJECTS\licenseplatereader\runs\detect\plate_detector
# Starting training for 45 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/45         0G      1.711          4      1.729         24        640: 1% ──────────── 17/1324 23.1s/it 7:22<8:23:319
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from ultralytics import YOLO
#       2 model = YOLO("yolov8n.pt")  # nano = lightweight
# ----> 3 results = model.train(
#       4     data=f"{dataset.location}/data.yaml",
#       5     epochs=45,
#       6     imgsz=640,
#       7     batch=16,
#       8     name="plate_detector"
#       9 )
#
# File d:\PROJECTS\licenseplatereader\.venv\Lib\site-packages\ultralytics\engine\model.py:788, in Model.train(self, trainer, **kwargs)
#     785     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     786     self.model = self.trainer.model
# --> 788 self.trainer.train()
#     789 # Update model and cfg after training
#     790 if RANK in {-1, 0}:
#
# File d:\PROJECTS\licenseplatereader\.venv\Lib\site-packages\ultralytics\engine\trainer.py:244, in BaseTrainer.train(self)
#     241         ddp_cleanup(self, str(file))
#     243 else:
# --> 244     self._do_train()
#
# File d:\PROJECTS\licenseplatereader\.venv\Lib\site-packages\ultralytics\engine\trainer.py:465, in BaseTrainer._do_train(self)
#     463     break  # restart epoch loop with reduced batch size
#     464 if ni - last_opt_step >= self.accumulate:
# --> 465     self.optimizer_step()
#     466     last_opt_step = ni
#     468     # Timed stopping
#
# File d:\PROJECTS\licenseplatereader\.venv\Lib\site-packages\ultralytics\engine\trainer.py:726, in BaseTrainer.optimizer_step(self)
#     724 self.scaler.unscale_(self.optimizer)  # unscale gradients
#     725 torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=10.0)
# --> 726 self.scaler.step(self.optimizer)
#     727 self.scaler.update()
#     728 self.optimizer.zero_grad()
#
# File d:\PROJECTS\licenseplatereader\.venv\Lib\site-packages\torch\amp\grad_scaler.py:400, in GradScaler.step(self, optimizer, *args, **kwargs)
#     378 """Invoke ``unscale_(optimizer)`` followed by parameter update, if gradients are not infs/NaN.
#     379
#     380 :meth:`step` carries out the following two operations:
#    (...)    397     Closure use is not currently supported.
#     398 """
#     399 if not self._enabled:
# --> 400     return optimizer.step(*args, **kwargs)
#     402 if "closure" in kwargs:
#     403     raise RuntimeError(
#     404         "Closure use is not currently supported if GradScaler is enabled."
#     405     )
#
# File d:\PROJECTS\licenseplatereader\.venv\Lib\site-packages\torch\optim\lr_scheduler.py:166, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     164 opt = opt_ref()
#     165 opt._opt_called = True  # type: ignore[union-attr]
# --> 166 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File d:\PROJECTS\licenseplatereader\.venv\Lib\site-packages\torch\optim\optimizer.py:533, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     528             raise RuntimeError(
#     529                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     530             )
#     532 # pyrefly: ignore [invalid-param-spec]
# --> 533 out = func(*args, **kwargs)
#     534 self._optimizer_step_code()
#     536 # call optimizer step post hooks
#
# File d:\PROJECTS\licenseplatereader\.venv\Lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File d:\PROJECTS\licenseplatereader\.venv\Lib\site-packages\ultralytics\optim\muon.py:218, in MuSGD.step(self, closure)
#     215     state["momentum_buffer"] = torch.zeros_like(p)
#     216     state["momentum_buffer_SGD"] = torch.zeros_like(p)
# --> 218 update = muon_update(
#     219     grad, state["momentum_buffer"], beta=group["momentum"], nesterov=group["nesterov"]
#     220 )
#     221 p.add_(update.reshape(p.shape), alpha=-(lr * self.muon))
#     223 # SGD update
#
# File d:\PROJECTS\licenseplatereader\.venv\Lib\site-packages\ultralytics\optim\muon.py:94, in muon_update(grad, momentum, beta, nesterov)
#      92 if update.ndim == 4:  # for the case of conv filters
#      93     update = update.view(len(update), -1)
# ---> 94 update = zeropower_via_newtonschulz5(update)
#      95 update *= max(1, grad.size(-2) / grad.size(-1)) ** 0.5
#      96 return update
#
# File d:\PROJECTS\licenseplatereader\.venv\Lib\site-packages\ultralytics\optim\muon.py:53, in zeropower_via_newtonschulz5(G, eps)
#      51     A = X @ X.T
#      52     B = b * A + c * A @ A
# ---> 53     X = a * X + B @ X
#      54 if G.size(0) > G.size(1):
#      55     X = X.T
#
# KeyboardInterrupt:

# %%
from ultralytics import YOLO
model = YOLO("runs/detect/sg_plate_detector/weights/best.pt")
metrics = model.val()
print(f"mAP@0.5:      {metrics.box.map50:.3f}")
print(f"mAP@0.5:0.95: {metrics.box.map:.3f}")
print(f"Precision:    {metrics.box.mp:.3f}")
print(f"Recall:       {metrics.box.mr:.3f}")
